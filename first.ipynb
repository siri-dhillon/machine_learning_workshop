# %% [markdown]
# # First Jupyter Notebook!
# This Notebook is used to verify that code block are geting executed.
#
# Steps:
# 1. Go to Extensions in vscode and type "jupyter"
# 2. Click and install the Jupyter Extension as shown below.
# ![image.png](attachment:image.png)
# 3. Open this Notebook and click on "Select Kernel" on top right of this notebook. Select the Python version installed on your machine. Alternatively, follow the setup steps in vscode "Getting Started with..." page. The goal is to add a kernel through which your python code can be executed on this notebook.
# ![image-2.png](attachment:image-2.png)
# 4. Go to the Hello World code block (or create a new code block). Run using 'CTRL + ENTER' or the triangular Run button on the left of the code block.
# ![image-3.png](attachment:image-3.png)
#
# If everything is set up and configured correctly, your Hello World Out put will be printed below the code block.
#
#
# To set up for the rest of the Machine Learning Tutorial, install the prerequisites:
# `pip install -r requirements.txt`
#
# Alternatively, install them separately using `pip install ...` command.

# %%
print("Hello World!")
